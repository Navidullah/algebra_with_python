# %% [markdown]
# ### How to calculate the Slope of curve

# %%
x1 = 1
y1 = 7
x2 = 2
y2 = 10

slope = (y2 - y1) / (x2 - x1)

print("slope = ", slope)
# Out:
# slope =  3.0

# %% [markdown]
# ### Next, Developing Equations

# %%
x1 = 632 #1
y1 = 84 #7
x2 = 1800 #2
y2 = 8 #10

# The slope is "m"
m = (y2 - y1) / (x2 - x1)

# The y intercept is "b"
b = y1 - m*x1

# The full equation
print("y = ", m, "x + ", b)
# Out:
# y =  -0.06506849315068493 x +  125.12328767123287

# %%
x11 = 1
y11 = 7
x22 = 2
y22 = 10

# The slope is "m"

m = (y22 - y11) / (x22 - x11)
# The y intercept is "b"
b = y11 - m*x11

# The full equation
print("y = ", m, "x + ", b)
# Out:
# y =  3.0 x +  4.0

# %% [markdown]
# ### Display the Graph

# %%
import matplotlib.pyplot as plt
import numpy as np

x1 = 1
y1 = 7
x2 = 2
y2 = 10
xmin = -10
xmax = 10
ymin = -10
ymax = 10
points = 2*(xmax-xmin)
x = np.linspace(xmin, xmax, points)

# Develop the equation y = mx + b
m = (y2 - y1) / (x2 - x1)
b = y1 - m*x1
print("y = ", m, "x + ", b)

# For the graph
xmin = -10
xmax = 10
ymin = -10
ymax = 10

# For the line on the graph


# Basic setup for the graph
fig, ax = plt.subplots()
plt.axis([xmin,xmax,ymin,ymax]) # window size
plt.plot([xmin,xmax],[0,0],'b') # blue x axis
plt.plot([0,0],[ymin,ymax], 'b') # blue y axis
ax.set_xlabel("x values") #set the x label
ax.set_ylabel("y values") #set the y label
ax.set_title("Graph Title") #set the title
ax.grid(True) #set the grid

ax.set_xticks(np.arange(xmin, xmax+1, 1)) 
ax.set_yticks(np.arange(ymin, ymax+1, 1))

y = m*x +b
# Plot the linear function as a red line
plt.plot(x,y,'r', label=f'y={m:.2f}x+{b:.2f}')
plt.legend()

plt.show()
# Out:
# y =  3.0 x +  4.0

# %%
import matplotlib.pyplot as plt
import numpy as np
x1 = 2
y1 = 3
x2 = 6
y2 = 8

xmin = -10
xmax = 10
ymin = -10
ymax = 10
points = 2*(xmax-xmin)
x = np.linspace(xmin, xmax, points)



# Develop the equation y = mx + b
m = (y2 - y1) / (x2 - x1)
b = y1 - m*x1
print("y = ", m, "x + ", b)
y = m*x + b

fig, ax = plt.subplots()
plt.axis([xmin,xmax,ymin,ymax]) # window size
plt.plot([xmin,xmax],[0,0],'b') # blue x axis
plt.plot([0,0],[ymin,ymax], 'b') # blue y axis

ax.set_xlabel("x values") #set the x label
ax.set_ylabel("y values") #set the y label
ax.set_title("Graph Title") #set the title
ax.grid(True) #set the grid

ax.set_xticks(np.arange(xmin, xmax+1, 1)) 
ax.set_yticks(np.arange(ymin, ymax+1, 1))

plt.plot(x, y, label=f'y={m:.2f}x+{b:.2f}')

plt.legend()
plt.show()
# Out:
# y =  1.25 x +  0.5
